# %%
import pandas as pd
import numpy as np

# %%
test = pd.read_csv( 'application_test.csv')
train = pd.read_csv('application_train.csv')
bureau_balance = pd.read_csv('bureau_balance.csv')
credit_card_balance = pd.read_csv('credit_card_balance.csv')
POS_CASH_balance = pd.read_csv('POS_CASH_balance.csv')
previous_application = pd.read_csv('previous_application.csv')
sample_submission = pd.read_csv('sample_submission.csv')
HomeCredit_columns_description = pd.read_csv('HomeCredit_columns_description.csv', encoding='ISO-8859-1')
installments_payments = pd.read_csv('installments_payments.csv')
bureau=pd.read_csv('bureau.csv')

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)


HomeCredit_columns_description
# Out:
#      Unnamed: 0                         Table                           Row  \
# 0             1  application_{train|test}.csv                    SK_ID_CURR
# 1             2  application_{train|test}.csv                        TARGET
# 2             5  application_{train|test}.csv            NAME_CONTRACT_TYPE
# 3             6  application_{train|test}.csv                   CODE_GENDER
# 4             7  application_{train|test}.csv                  FLAG_OWN_CAR
# 5             8  application_{train|test}.csv               FLAG_OWN_REALTY
# 6             9  application_{train|test}.csv                  CNT_CHILDREN
# 7            10  application_{train|test}.csv              AMT_INCOME_TOTAL
# 8            11  application_{train|test}.csv                    AMT_CREDIT
# 9            12  application_{train|test}.csv                   AMT_ANNUITY
# 10           13  application_{train|test}.csv               AMT_GOODS_PRICE
# ...

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
pd.reset_option('display.max_colwidth')

# %%
import pandas as pd

# Charger les données
train = pd.read_csv('application_train.csv')
test = pd.read_csv('application_test.csv')
bureau = pd.read_csv('bureau.csv')

# Combiner les identifiants de train et test
all_ids = pd.concat([train['SK_ID_CURR'], test['SK_ID_CURR']]).unique()

# Filtrer bureau pour les entrées correspondant à SK_ID_CURR dans train ou test
bureau_filtered = bureau[bureau['SK_ID_CURR'].isin(all_ids)]

# Aggregations
agg_bureau = bureau_filtered.groupby('SK_ID_CURR').agg({
    'DAYS_CREDIT': ['mean', 'min', 'max'],
    'CREDIT_DAY_OVERDUE': ['mean'],
    'DAYS_CREDIT_ENDDATE': ['min'],
    'DAYS_ENDDATE_FACT': ['mean', 'max'],
    'AMT_CREDIT_MAX_OVERDUE': ['mean'],
    'CNT_CREDIT_PROLONG': ['sum'],
    'AMT_CREDIT_SUM': ['sum'],
    'AMT_CREDIT_SUM_DEBT': ['sum'],
    'AMT_CREDIT_SUM_OVERDUE': ['mean'],
    'DAYS_CREDIT_UPDATE': ['mean'],
    'AMT_ANNUITY': ['mean']
})

# Renommer les colonnes
agg_bureau.columns = ['_'.join(col).strip() for col in agg_bureau.columns.values]

# Compter les différents statuts de crédit actif
credit_active_dummies = pd.get_dummies(bureau_filtered['CREDIT_ACTIVE'], prefix='ca')
credit_active_dummies = credit_active_dummies.mul(bureau_filtered['SK_ID_CURR'], axis=0)
credit_active_counts = credit_active_dummies.groupby('SK_ID_CURR').sum()

# Compter les types de crédit
credit_type_dummies = pd.get_dummies(bureau_filtered['CREDIT_TYPE'], prefix='ct')
credit_type_dummies = credit_type_dummies.mul(bureau_filtered['SK_ID_CURR'], axis=0)
credit_type_counts = credit_type_dummies.groupby('SK_ID_CURR').sum()

# Devise la plus fréquente
most_frequent_currency = bureau_filtered.groupby('SK_ID_CURR')['CREDIT_CURRENCY'].agg(lambda x: x.value_counts().index[0])

# Fusionner toutes les informations
bureau_final = agg_bureau.join(credit_active_counts, on='SK_ID_CURR', how='left')
bureau_final = bureau_final.join(credit_type_counts, on='SK_ID_CURR', how='left')
bureau_final = bureau_final.join(most_frequent_currency, on='SK_ID_CURR', how='left')

# Fusionner avec train et test
train = train.join(bureau_final, on='SK_ID_CURR', how='left')
test = test.join(bureau_final, on='SK_ID_CURR', how='left')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 35
#      33 credit_active_dummies = pd.get_dummies(bureau_filtered['CREDIT_ACTIVE'], prefix='ca')
#      34 credit_active_dummies = credit_active_dummies.mul(bureau_filtered['SK_ID_CURR'], axis=0)
# ---> 35 credit_active_counts = credit_active_dummies.groupby('SK_ID_CURR').sum()
#      37 # Compter les types de crédit
#      38 credit_type_dummies = pd.get_dummies(bureau_filtered['CREDIT_TYPE'], prefix='ct')
#
# File ~\Desktop\FormationOpenClassRooms\Projet3\myenv\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
# ...

# %%
import pandas as pd

# Liste des DataFrames
datasets = [ train, bureau_balance, credit_card_balance, POS_CASH_balance,
            previous_application, sample_submission, HomeCredit_columns_description, installments_payments, bureau]

# Liste des noms des DataFrames
names = [ 'train', 'bureau_balance', 'credit_card_balance', 'POS_CASH_balance',
         'previous_application', 'sample_submission', 'HomeCredit_columns_description', 'installments_payments', 'bureau']

# Créer un dictionnaire pour stocker les noms de colonnes de chaque DataFrame
columns_dict = {}

# Remplir le dictionnaire avec les noms de colonnes de chaque DataFrame
for df, name in zip(datasets, names):
    columns_dict[name] = set(df.columns)

# Initialiser un dictionnaire pour stocker les datasets contenant chaque colonne commune
common_columns_datasets = {}

# Trouver les noms de colonnes communs à au moins deux DataFrames et les datasets qui les contiennent
for name, columns in columns_dict.items():
    for column in columns:
        for other_name, other_columns in columns_dict.items():
            if column in other_columns:
                if column not in common_columns_datasets:
                    common_columns_datasets[column] = set()
                common_columns_datasets[column].update([name, other_name])

# Filtrer pour ne garder que les colonnes présentes dans au moins deux datasets
common_columns_datasets = {col: datasets for col, datasets in common_columns_datasets.items() if len(datasets) > 1}

# Convertir le dictionnaire en DataFrame pour une meilleure visualisation
common_columns_df = pd.DataFrame(list(common_columns_datasets.items()), columns=['Common_Column', 'Datasets'])

# Afficher le DataFrame des noms de colonnes communs et des datasets qui les contiennent
common_columns_df

# %%
def change_columns_names(data, columns, suffix):
    # Liste des noms de colonnes à modifier
    
    
    # Ajouter le suffixe 'PREV' aux colonnes spécifiées dans previous_application
    for col in columns:
        if col in data.columns:
            data.rename(columns={col: f'{col}_'+suffix}, inplace=True)
    
    # Afficher les nouvelles colonnes pour vérification
    print(data.columns)

# %%
columns = ['AMT_ANNUITY']
suffix='BU'

change_columns_names(bureau, columns, suffix)

# %%
columns = ['MONTHS_BALANCE']
suffix='BB'

change_columns_names(bureau_balance, columns, suffix)

# %%
columns = ['MONTHS_BALANCE','NAME_CONTRACT_STATUS']
suffix='PCB'

change_columns_names(POS_CASH_balance, columns, suffix)

# %%
columns = ['MONTHS_BALANCE','NAME_CONTRACT_STATUS']
suffix='CCB'

change_columns_names(credit_card_balance, columns, suffix)

# %%
columns = [
        'WEEKDAY_APPR_PROCESS_START',
        'AMT_ANNUITY',
        'AMT_GOODS_PRICE',
        'AMT_CREDIT',
        'NAME_CONTRACT_TYPE',
        'NAME_TYPE_SUITE',
        'HOUR_APPR_PROCESS_START',
        'NAME_CONTRACT_STATUS'
    ]
suffix='PREV'

change_columns_names(previous_application, columns, suffix)

# %%
print(train.shape)

# %%
print("Unique SK_ID_CURR in train:", train['SK_ID_CURR'].nunique())
print("Total entries in train:", len(train))

# %%
# Agréger bureau_balance par SK_ID_BUREAU
bureau_balance_agg = bureau_balance.groupby('SK_ID_BUREAU').agg({'MONTHS_BALANCE_BB': ['mean']})
bureau_balance_agg.columns = ['BB_' + '_'.join(col).strip() for col in bureau_balance_agg.columns.values]

# %%
# Fusionnez le résultat agrégé avec bureau sur SK_ID_BUREAU.
bureau = bureau.merge(bureau_balance_agg, on='SK_ID_BUREAU', how='left')

# %%
print("Unique SK_ID_CURR in bureau:", bureau['SK_ID_CURR'].nunique())
print("Total entries in bureau:", len(bureau))

# %%
bureau['CREDIT_CURRENCY'].unique()

# %%
bureau['CREDIT_CURRENCY']

# %%
import pandas as pd


# Combiner les identifiants de train et test
all_ids = pd.concat([train['SK_ID_CURR'], test['SK_ID_CURR']]).unique()

# Filtrer bureau pour les entrées correspondant à SK_ID_CURR dans train ou test
bureau_filtered = bureau[bureau['SK_ID_CURR'].isin(all_ids)]

# Filtrer bureau_balance pour les entrées correspondant à SK_ID_BUREAU dans bureau_filtered
bureau_balance_filtered = bureau_balance[bureau_balance['SK_ID_BUREAU'].isin(bureau_filtered['SK_ID_BUREAU'])]

# Effectuer le regroupement sur bureau_balance_filtered
bureau_balance_agg = bureau_balance_filtered.groupby('SK_ID_BUREAU').agg({'MONTHS_BALANCE_BB': 'mean'})
bureau_balance_agg.columns = ['MONTHS_BALANCE_BB_MEAN']

# Fusionner bureau_balance_agg avec bureau_filtered puis avec train et test
bureau_filtered = bureau_filtered.merge(bureau_balance_agg, on='SK_ID_BUREAU', how='left')
train = train.merge(bureau_filtered, on='SK_ID_CURR', how='left')
test = test.merge(bureau_filtered, on='SK_ID_CURR', how='left')

# %%
pd.set_option('display.max_columns', None)

train.head(5)

# %%
print(train.shape)

# %%
presence_rate(train)

# %%
# Aggréger les données de credit_card_balance par SK_ID_CURR
credit_card_balance_agg = credit_card_balance.groupby('SK_ID_CURR').agg({
    'AMT_BALANCE': 'mean',  # Exemple d'agrégation
    'CNT_DRAWINGS_CURRENT': 'sum'
})

# Renommer les colonnes pour éviter les conflits lors de la fusion
credit_card_balance_agg = credit_card_balance_agg.rename(columns={
    'AMT_BALANCE': 'AVG_AMT_BALANCE',
    'CNT_DRAWINGS_CURRENT': 'TOTAL_CNT_DRAWINGS_CURRENT'
})

# %%
import pandas as pd

def cat_variables_with_high_presence(data, threshold=90):
    """
    Retourne la liste des variables numériques dont le taux de présence est supérieur au seuil donné.

    :param data: DataFrame contenant les données.
    :param threshold: Seuil de présence en pourcentage.
    :return: Liste des noms des variables numériques avec un taux de présence supérieur au seuil.
    """
    # Initialiser une liste pour stocker les noms des variables qui répondent au critère
    high_presence_vars = []

    # Calculer le taux de présence pour chaque variable numérique
    for col in data.select_dtypes(exclude=[np.number]).columns:
        presence_rate = 100 * data[col].notnull().mean()
        if presence_rate >= threshold:
            high_presence_vars.append(col)

    return high_presence_vars

# %%
import pandas as pd

def num_variables_with_high_presence(data, threshold=90):
    """
    Retourne la liste des variables numériques dont le taux de présence est supérieur au seuil donné.

    :param data: DataFrame contenant les données.
    :param threshold: Seuil de présence en pourcentage.
    :return: Liste des noms des variables numériques avec un taux de présence supérieur au seuil.
    """
    # Initialiser une liste pour stocker les noms des variables qui répondent au critère
    high_presence_vars = []

    # Calculer le taux de présence pour chaque variable numérique
    for col in data.select_dtypes(include=[np.number]).columns:
        presence_rate = 100 * data[col].notnull().mean()
        if presence_rate >= threshold:
            high_presence_vars.append(col)

    return high_presence_vars

# %%
import pandas as pd
import numpy as np

def remove_outliers(data, variables_list, num_std=3):
    """
    Supprime les valeurs aberrantes des variables spécifiées dans un DataFrame.

    :param data: DataFrame contenant les données.
    :param variables_list: Liste des noms des variables à nettoyer.
    :param num_std: Nombre d'écarts-types utilisés pour définir une valeur aberrante.
    :return: DataFrame avec les valeurs aberrantes supprimées.
    """
    for var in variables_list:
        if var in data.columns:
            # Calculer la moyenne et l'écart-type
            mean, std = data[var].mean(), data[var].std()
            
            # Définir les seuils pour les valeurs aberrantes
            lower_bound, upper_bound = mean - num_std * std, mean + num_std * std
            
            # Remplacer les valeurs aberrantes par NaN ou une autre valeur spécifique
            data[var] = np.where(
                (data[var] > lower_bound) & (data[var] < upper_bound),
                data[var],
                np.NaN  # ou une autre valeur de votre choix
            )
    return data

# %%
# Exemple d'utilisation

threshold = 90  # Définir le seuil de présence
variables_list = num_variables_with_high_presence(train, threshold)
cleaned_train = remove_outliers(train, variables_list,num_std=2)
cleaned_train

# %%
import pandas as pd

def presence_rate(data):
    # Calculer le pourcentage de présence des données pour chaque colonne
    presence_rate = (1 - data.isnull().mean()) * 100
    
    # Trier la série presence_rate par valeurs décroissantes
    sorted_presence_rate = presence_rate.sort_values(ascending=False)
    
    # Formater chaque pourcentage avec deux chiffres après la virgule et ajouter le caractère '%'
    formatted_presence_rate = sorted_presence_rate.apply(lambda x: f'{x:.2f} %')
    
    # Retourner le taux de présence formaté et trié
    return formatted_presence_rate

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
presence_rate(cleaned_train)

# %%
presence_rate(train)

# %%
pd.reset_option('display.max_rows')
pd.reset_option('display.max_columns')
